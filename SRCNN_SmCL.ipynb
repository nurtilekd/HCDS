# %% [markdown]
# ### Packages + Configuration

# %%
import gc
import json
import math
import runpy
from pathlib import Path

import numpy as np

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

years = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
variable  = "2m_temperature"

seed = 0

epochs = 400
lr = 1e-4
batch_size = 32
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
pin_memory = (device.type == "cuda")

dataset_dir = Path.cwd() / "input_labels"

# %% [markdown]
# ### Load data and check if normalized

# %%
def to_nchw(a: np.ndarray) -> np.ndarray:
    a = np.asarray(a)
    if a.ndim == 3:
        a = a[:, None, :, :]
    elif a.ndim == 4:
        if a.shape[1] in (1, 3):
            pass
        elif a.shape[-1] in (1, 3):
            a = a.transpose(0, 3, 1, 2)
    return a.astype(np.float32)

files = []
for year in years:
    files.append(dataset_dir / f"{variable}" / f"{year}_{variable}.npz")

N = 0
C = H = W = None
for file in files:
    with np.load(file) as data:
        X0 = to_nchw(data["X"])
        if C is None:
            _, C, H, W = X0.shape
        N += X0.shape[0]
        del X0
gc.collect()

X = np.empty((N, C, H, W), dtype=np.float32)
Y = np.empty((N, C, H, W), dtype=np.float32)

offset = 0
for file in files:
    with np.load(file) as data:
        X0 = to_nchw(data["X"])
        Y0 = to_nchw(data["Y"])
    n0 = X0.shape[0]
    X[offset:offset+n0] = X0
    Y[offset:offset+n0] = Y0
    offset += n0
    del X0, Y0
gc.collect()

def check_0_1(name: str, a: np.ndarray, tol: float = 1e-6):
    amin = float(np.nanmin(a))
    amax = float(np.nanmax(a))
    ok = (amin >= -tol) and (amax <= 1.0 + tol)
    if ok:
        print(f"The data is properly normalized: min = {amin:.6f}, max = {amax:.6f}")
    if not ok:
        raise ValueError(
            print(f"The normalization step is missing or inconsistent: min = {amin:.6f}, max = {amax:.6f}")
        )

check_0_1("X", X)
check_0_1("Y", Y)

np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

n = len(X)
train_n = int(0.8 * n)
val_n = int(0.1 * n)

rng = np.random.default_rng(seed)
perm = rng.permutation(n)

train_idx = perm[:train_n]
val_idx   = perm[train_n:train_n + val_n]
test_idx  = perm[train_n + val_n:]
# Out:
# The data is properly normalized: min = 0.010022, max = 0.988940
# The data is properly normalized: min = 0.000000, max = 1.000000

# %% [markdown]
# ### Prepare data

# %%
class FullDataset(Dataset):
    def __init__(self, X, Y, indices):
        self.X = X
        self.Y = Y
        self.indices = np.asarray(indices)

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, i):
        idx = self.indices[i]
        return torch.from_numpy(self.X[idx]), torch.from_numpy(self.Y[idx])

train_ds = FullDataset(X, Y, train_idx)
val_ds   = FullDataset(X, Y, val_idx)
test_ds  = FullDataset(X, Y, test_idx)

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True,  num_workers=0, pin_memory=pin_memory)
val_loader   = DataLoader(val_ds,   batch_size=1,          shuffle=False, num_workers=0, pin_memory=pin_memory)
test_loader  = DataLoader(test_ds,  batch_size=1,          shuffle=False, num_workers=0, pin_memory=pin_memory)

# %% [markdown]
# ### Model + Evaluator

# %%
# SmCL (SoftMax Contraining Layer)
class SmCL(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, z_hr: torch.Tensor, x_hr: torch.Tensor) -> torch.Tensor:
        B, C, H, W = z_hr.shape
        if (H % 2) != 0 or (W % 2) != 0:
            raise ValueError(f"H,W must be divisible by 2. Got {H}x{W}, scale = {2}")

        Hs, Ws = H // 2, W // 2

        x_lr = F.avg_pool2d(x_hr, kernel_size=2, stride=2)

        z = z_hr.view(B, C, Hs, 2, Ws, 2)
        z_flat = z.permute(0, 1, 2, 4, 3, 5).contiguous().view(B, C, Hs, Ws, 2 * 2)

        w_flat = torch.softmax(z_flat, dim=-1)
        w = w_flat.view(B, C, Hs, Ws, 2, 2).permute(0, 1, 2, 4, 3, 5).contiguous()

        x_lr_b = x_lr.view(B, C, Hs, 1, Ws, 1)
        y = w * (x_lr_b * (2 * 2))

        return y.view(B, C, H, W)

# simple SRCNN + SmCL tail
class SRCNN_SmCL(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 64, kernel_size=9, padding=4)
        self.conv2 = nn.Conv2d(64, 32, kernel_size=1, padding=0)
        self.conv3 = nn.Conv2d(32, 1, kernel_size=5, padding=2)
        self.smcl = SmCL()

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        z = F.relu(self.conv1(x))
        z = F.relu(self.conv2(z))
        z = self.conv3(z)
        return self.smcl(z, x)

# metric for evaluating "on the run"
@torch.no_grad()
def eval_loss(loader, model, device):
    model.eval()
    total_loss = 0.0
    n = 0

    for x, y in loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        pred = model(x)
        total_loss += F.l1_loss(pred, y, reduction="sum").item()
        n += y.numel()

    return total_loss / max(n, 1)

# Metric for final test set evaluation
@torch.no_grad()
def eval_mae_rmse(loader, model, device, baseline: bool = False):
    model.eval()
    abs_sum = 0.0
    sq_sum = 0.0
    n = 0

    for x, y in loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        pred = x if baseline else model(x)

        diff = pred - y
        abs_sum += diff.abs().sum().item()
        sq_sum  += (diff * diff).sum().item()
        n += y.numel()

    mae = abs_sum / max(n, 1)
    rmse = math.sqrt(sq_sum / max(n, 1))
    return mae, rmse

# define model
model = SRCNN_SmCL().to(device)

# %% [markdown]
# ### Training Loop

# %%
# Create a path where we will store current run data
run_dir = Path("runs") / f"SRCNN_SmCL_{variable}" 
run_dir.mkdir(parents=True, exist_ok=True)

# Path for report.json what will store important information about the run
report_path = run_dir / "report.json"

# Fill in the training configuration (these don't depend on post-training data)
report = {
    "config": {
        "model": "SRCNN_SmCL",
        "years": years,
        "variable": variable,

        "seed": seed,
        
        "epochs": epochs,
        "lr": lr,
        "batch_size": batch_size,
        "device": str(device),
    }
}

#=========================================================================================#

def train():
    opt = torch.optim.Adam(model.parameters(), lr=lr)

    # Store intermediate losses for plotting later
    train_hist = []
    val_hist = []
    epoch_hist = []

    # Here we will store the best checkpoint
    best_val = float("inf")
    ckpt_path_best = run_dir / "best_model.pt"

    #=========================================================================================#
    
    # Calculate the baseline metrics and add to report
    baseline_mae, baseline_rmse = eval_mae_rmse(test_loader, model, device, baseline=True)
    
    print(f"[BASELINE ERROR | IDENTITY MODEL] test_MAE={baseline_mae:.6f} | test_RMSE={baseline_rmse:.6f}")

    report["baseline_error"] = {
        "mae": baseline_mae,
        "rmse": baseline_rmse,
    }

    #=========================================================================================#
    
    # Start iterating across epochs
    for epoch in range(1, epochs + 1):
        model.train()
        total_train_loss = 0.0
        n = 0

        for x, y in train_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            opt.zero_grad(set_to_none=True)
            pred = model(x)
            loss = F.l1_loss(pred, y)

            loss.backward()
            opt.step()

            loss = F.l1_loss(pred, y, reduction="sum")
            total_train_loss += loss.item()
            n += y.numel()

        train_loss = total_train_loss / max(n, 1)
        val_loss = eval_loss(val_loader, model, device)

        print(f"epoch {epoch:03d} | train_loss = {train_loss:.6f} | val_loss = {val_loss:.6f}")

        epoch_hist.append(epoch)
        train_hist.append(train_loss)
        val_hist.append(val_loss)

        if val_loss < best_val:
            best_val = val_loss
            torch.save(
                {"state_dict": model.state_dict(), "best_val": best_val, "epoch": epoch},
                ckpt_path_best,
            )

    #=========================================================================================#
    
    # Plot the saved train and val losses saved during training
    fig, ax = plt.subplots(figsize=(7, 4), constrained_layout=True)
    ax.plot(epoch_hist, train_hist, label="train_loss")
    ax.plot(epoch_hist, val_hist, label="val_loss")
    ax.set_xlabel("epoch")
    ax.set_ylabel("loss")
    ax.set_title("Loss curve")
    ax.grid(True, alpha=0.3)
    ax.legend()
    fig.savefig(run_dir / f"SRCNN_SmCL_{variable}_loss_curve.png", dpi=150)
    plt.close(fig)

    #=========================================================================================#
    
    # Load the best checkpoint and evaluate it on the test set
    if ckpt_path_best.exists():
        ckpt = torch.load(ckpt_path_best, map_location=device)
        model.load_state_dict(ckpt["state_dict"])

    # Calculate the trained metrics and add to report
    test_mae, test_rmse = eval_mae_rmse(test_loader, model, device, baseline=False)
    
    print(f"[TRAINED ERROR | SRCNN_SmCL] test_MAE={test_mae:.6f} | test_RMSE={test_rmse:.6f}")

    report["trained_error"] = {
        "mae": test_mae,
        "rmse": test_rmse,
    }

    #=========================================================================================#
    
    # Calculate how much the model performace improved
    report["error_reduction"] = {
        "mae": 100.0 * (baseline_mae - test_mae) / baseline_mae if baseline_mae != 0 else float("nan"),
        "rmse": 100.0 * (baseline_rmse - test_rmse) / baseline_rmse if baseline_rmse != 0 else float("nan"),
    }

if __name__ == "__main__":
    train()
# Out:
# [BASELINE ERROR | IDENTITY MODEL] test_MAE=0.005972 | test_RMSE=0.010435
# epoch 001 | train_loss = 0.005304 | val_loss = 0.004764
# epoch 002 | train_loss = 0.004556 | val_loss = 0.004375
# epoch 003 | train_loss = 0.004283 | val_loss = 0.004205
# epoch 004 | train_loss = 0.004165 | val_loss = 0.004127
# epoch 005 | train_loss = 0.004108 | val_loss = 0.004086
# epoch 006 | train_loss = 0.004076 | val_loss = 0.004061
# epoch 007 | train_loss = 0.004055 | val_loss = 0.004043
# epoch 008 | train_loss = 0.004038 | val_loss = 0.004029
# epoch 009 | train_loss = 0.004026 | val_loss = 0.004017
# epoch 010 | train_loss = 0.004015 | val_loss = 0.004007
# epoch 011 | train_loss = 0.004006 | val_loss = 0.003999
# epoch 012 | train_loss = 0.003998 | val_loss = 0.003991
# epoch 013 | train_loss = 0.003990 | val_loss = 0.003985
# epoch 014 | train_loss = 0.003983 | val_loss = 0.003977
# epoch 015 | train_loss = 0.003977 | val_loss = 0.003973
# epoch 016 | train_loss = 0.003972 | val_loss = 0.003967
# epoch 017 | train_loss = 0.003967 | val_loss = 0.003963
# epoch 018 | train_loss = 0.003963 | val_loss = 0.003960
# epoch 019 | train_loss = 0.003959 | val_loss = 0.003955
# epoch 020 | train_loss = 0.003956 | val_loss = 0.003953
# epoch 021 | train_loss = 0.003952 | val_loss = 0.003948
# epoch 022 | train_loss = 0.003949 | val_loss = 0.003945
# epoch 023 | train_loss = 0.003947 | val_loss = 0.003942
# epoch 024 | train_loss = 0.003944 | val_loss = 0.003940
# epoch 025 | train_loss = 0.003941 | val_loss = 0.003936
# epoch 026 | train_loss = 0.003938 | val_loss = 0.003934
# epoch 027 | train_loss = 0.003936 | val_loss = 0.003933
# epoch 028 | train_loss = 0.003934 | val_loss = 0.003929
# epoch 029 | train_loss = 0.003932 | val_loss = 0.003927
# epoch 030 | train_loss = 0.003929 | val_loss = 0.003925
# epoch 031 | train_loss = 0.003927 | val_loss = 0.003923
# epoch 032 | train_loss = 0.003925 | val_loss = 0.003921
# epoch 033 | train_loss = 0.003923 | val_loss = 0.003919
# epoch 034 | train_loss = 0.003921 | val_loss = 0.003918
# epoch 035 | train_loss = 0.003919 | val_loss = 0.003915
# epoch 036 | train_loss = 0.003918 | val_loss = 0.003914
# epoch 037 | train_loss = 0.003916 | val_loss = 0.003912
# epoch 038 | train_loss = 0.003914 | val_loss = 0.003912
# epoch 039 | train_loss = 0.003913 | val_loss = 0.003908
# epoch 040 | train_loss = 0.003911 | val_loss = 0.003908
# epoch 041 | train_loss = 0.003910 | val_loss = 0.003906
# epoch 042 | train_loss = 0.003908 | val_loss = 0.003904
# epoch 043 | train_loss = 0.003907 | val_loss = 0.003904
# epoch 044 | train_loss = 0.003905 | val_loss = 0.003901
# epoch 045 | train_loss = 0.003904 | val_loss = 0.003901
# epoch 046 | train_loss = 0.003903 | val_loss = 0.003898
# epoch 047 | train_loss = 0.003901 | val_loss = 0.003897
# epoch 048 | train_loss = 0.003899 | val_loss = 0.003896
# epoch 049 | train_loss = 0.003898 | val_loss = 0.003893
# epoch 050 | train_loss = 0.003897 | val_loss = 0.003893
# epoch 051 | train_loss = 0.003895 | val_loss = 0.003891
# epoch 052 | train_loss = 0.003894 | val_loss = 0.003891
# epoch 053 | train_loss = 0.003893 | val_loss = 0.003889
# epoch 054 | train_loss = 0.003892 | val_loss = 0.003888
# epoch 055 | train_loss = 0.003891 | val_loss = 0.003888
# epoch 056 | train_loss = 0.003889 | val_loss = 0.003886
# epoch 057 | train_loss = 0.003888 | val_loss = 0.003885
# epoch 058 | train_loss = 0.003887 | val_loss = 0.003884
# epoch 059 | train_loss = 0.003887 | val_loss = 0.003882
# epoch 060 | train_loss = 0.003885 | val_loss = 0.003883
# epoch 061 | train_loss = 0.003884 | val_loss = 0.003882
# epoch 062 | train_loss = 0.003883 | val_loss = 0.003880
# epoch 063 | train_loss = 0.003882 | val_loss = 0.003879
# epoch 064 | train_loss = 0.003881 | val_loss = 0.003877
# epoch 065 | train_loss = 0.003881 | val_loss = 0.003876
# epoch 066 | train_loss = 0.003879 | val_loss = 0.003876
# epoch 067 | train_loss = 0.003878 | val_loss = 0.003876
# epoch 068 | train_loss = 0.003878 | val_loss = 0.003875
# epoch 069 | train_loss = 0.003877 | val_loss = 0.003874
# epoch 070 | train_loss = 0.003876 | val_loss = 0.003873
# epoch 071 | train_loss = 0.003875 | val_loss = 0.003871
# epoch 072 | train_loss = 0.003875 | val_loss = 0.003873
# epoch 073 | train_loss = 0.003874 | val_loss = 0.003870
# epoch 074 | train_loss = 0.003873 | val_loss = 0.003869
# epoch 075 | train_loss = 0.003872 | val_loss = 0.003870
# epoch 076 | train_loss = 0.003871 | val_loss = 0.003867
# epoch 077 | train_loss = 0.003871 | val_loss = 0.003867
# epoch 078 | train_loss = 0.003870 | val_loss = 0.003866
# epoch 079 | train_loss = 0.003869 | val_loss = 0.003866
# epoch 080 | train_loss = 0.003869 | val_loss = 0.003865
# epoch 081 | train_loss = 0.003868 | val_loss = 0.003863
# epoch 082 | train_loss = 0.003867 | val_loss = 0.003865
# epoch 083 | train_loss = 0.003866 | val_loss = 0.003864
# epoch 084 | train_loss = 0.003865 | val_loss = 0.003862
# epoch 085 | train_loss = 0.003865 | val_loss = 0.003862
# epoch 086 | train_loss = 0.003864 | val_loss = 0.003861
# epoch 087 | train_loss = 0.003863 | val_loss = 0.003861
# epoch 088 | train_loss = 0.003862 | val_loss = 0.003859
# epoch 089 | train_loss = 0.003861 | val_loss = 0.003860
# epoch 090 | train_loss = 0.003861 | val_loss = 0.003858
# epoch 091 | train_loss = 0.003860 | val_loss = 0.003857
# epoch 092 | train_loss = 0.003859 | val_loss = 0.003856
# epoch 093 | train_loss = 0.003859 | val_loss = 0.003856
# epoch 094 | train_loss = 0.003859 | val_loss = 0.003856
# epoch 095 | train_loss = 0.003858 | val_loss = 0.003854
# epoch 096 | train_loss = 0.003856 | val_loss = 0.003855
# epoch 097 | train_loss = 0.003856 | val_loss = 0.003853
# epoch 098 | train_loss = 0.003856 | val_loss = 0.003852
# epoch 099 | train_loss = 0.003855 | val_loss = 0.003851
# epoch 100 | train_loss = 0.003855 | val_loss = 0.003853
# epoch 101 | train_loss = 0.003853 | val_loss = 0.003850
# epoch 102 | train_loss = 0.003852 | val_loss = 0.003849
# epoch 103 | train_loss = 0.003852 | val_loss = 0.003850
# epoch 104 | train_loss = 0.003851 | val_loss = 0.003849
# epoch 105 | train_loss = 0.003851 | val_loss = 0.003849
# epoch 106 | train_loss = 0.003850 | val_loss = 0.003846
# epoch 107 | train_loss = 0.003849 | val_loss = 0.003847
# epoch 108 | train_loss = 0.003848 | val_loss = 0.003845
# epoch 109 | train_loss = 0.003847 | val_loss = 0.003844
# epoch 110 | train_loss = 0.003847 | val_loss = 0.003844
# epoch 111 | train_loss = 0.003846 | val_loss = 0.003844
# epoch 112 | train_loss = 0.003847 | val_loss = 0.003842
# epoch 113 | train_loss = 0.003845 | val_loss = 0.003843
# epoch 114 | train_loss = 0.003844 | val_loss = 0.003841
# epoch 115 | train_loss = 0.003843 | val_loss = 0.003840
# epoch 116 | train_loss = 0.003842 | val_loss = 0.003839
# epoch 117 | train_loss = 0.003842 | val_loss = 0.003840
# epoch 118 | train_loss = 0.003842 | val_loss = 0.003839
# epoch 119 | train_loss = 0.003840 | val_loss = 0.003838
# epoch 120 | train_loss = 0.003840 | val_loss = 0.003840
# epoch 121 | train_loss = 0.003840 | val_loss = 0.003837
# epoch 122 | train_loss = 0.003839 | val_loss = 0.003838
# epoch 123 | train_loss = 0.003839 | val_loss = 0.003837
# epoch 124 | train_loss = 0.003838 | val_loss = 0.003836
# epoch 125 | train_loss = 0.003838 | val_loss = 0.003836
# epoch 126 | train_loss = 0.003837 | val_loss = 0.003834
# epoch 127 | train_loss = 0.003836 | val_loss = 0.003834
# epoch 128 | train_loss = 0.003836 | val_loss = 0.003833
# epoch 129 | train_loss = 0.003835 | val_loss = 0.003833
# epoch 130 | train_loss = 0.003834 | val_loss = 0.003831
# epoch 131 | train_loss = 0.003834 | val_loss = 0.003834
# epoch 132 | train_loss = 0.003833 | val_loss = 0.003831
# epoch 133 | train_loss = 0.003833 | val_loss = 0.003829
# epoch 134 | train_loss = 0.003832 | val_loss = 0.003833
# epoch 135 | train_loss = 0.003832 | val_loss = 0.003829
# epoch 136 | train_loss = 0.003831 | val_loss = 0.003829
# epoch 137 | train_loss = 0.003831 | val_loss = 0.003828
# epoch 138 | train_loss = 0.003831 | val_loss = 0.003829
# epoch 139 | train_loss = 0.003829 | val_loss = 0.003828
# epoch 140 | train_loss = 0.003829 | val_loss = 0.003826
# epoch 141 | train_loss = 0.003829 | val_loss = 0.003828
# epoch 142 | train_loss = 0.003829 | val_loss = 0.003826
# epoch 143 | train_loss = 0.003828 | val_loss = 0.003825
# epoch 144 | train_loss = 0.003827 | val_loss = 0.003824
# epoch 145 | train_loss = 0.003827 | val_loss = 0.003824
# epoch 146 | train_loss = 0.003826 | val_loss = 0.003824
# epoch 147 | train_loss = 0.003826 | val_loss = 0.003823
# epoch 148 | train_loss = 0.003825 | val_loss = 0.003823
# epoch 149 | train_loss = 0.003825 | val_loss = 0.003822
# epoch 150 | train_loss = 0.003825 | val_loss = 0.003823
# epoch 151 | train_loss = 0.003824 | val_loss = 0.003822
# epoch 152 | train_loss = 0.003823 | val_loss = 0.003823
# epoch 153 | train_loss = 0.003823 | val_loss = 0.003822
# epoch 154 | train_loss = 0.003823 | val_loss = 0.003820
# epoch 155 | train_loss = 0.003822 | val_loss = 0.003819
# epoch 156 | train_loss = 0.003822 | val_loss = 0.003820
# epoch 157 | train_loss = 0.003822 | val_loss = 0.003818
# epoch 158 | train_loss = 0.003821 | val_loss = 0.003819
# epoch 159 | train_loss = 0.003820 | val_loss = 0.003818
# epoch 160 | train_loss = 0.003820 | val_loss = 0.003817
# epoch 161 | train_loss = 0.003819 | val_loss = 0.003818
# epoch 162 | train_loss = 0.003820 | val_loss = 0.003819
# epoch 163 | train_loss = 0.003819 | val_loss = 0.003817
# epoch 164 | train_loss = 0.003818 | val_loss = 0.003817
# epoch 165 | train_loss = 0.003818 | val_loss = 0.003815
# epoch 166 | train_loss = 0.003818 | val_loss = 0.003816
# epoch 167 | train_loss = 0.003818 | val_loss = 0.003815
# epoch 168 | train_loss = 0.003817 | val_loss = 0.003814
# epoch 169 | train_loss = 0.003816 | val_loss = 0.003814
# epoch 170 | train_loss = 0.003816 | val_loss = 0.003816
# epoch 171 | train_loss = 0.003815 | val_loss = 0.003813
# epoch 172 | train_loss = 0.003816 | val_loss = 0.003812
# epoch 173 | train_loss = 0.003815 | val_loss = 0.003814
# epoch 174 | train_loss = 0.003814 | val_loss = 0.003812
# epoch 175 | train_loss = 0.003814 | val_loss = 0.003813
# epoch 176 | train_loss = 0.003814 | val_loss = 0.003811
# epoch 177 | train_loss = 0.003813 | val_loss = 0.003810
# epoch 178 | train_loss = 0.003812 | val_loss = 0.003810
# epoch 179 | train_loss = 0.003812 | val_loss = 0.003810
# epoch 180 | train_loss = 0.003811 | val_loss = 0.003810
# epoch 181 | train_loss = 0.003812 | val_loss = 0.003809
# epoch 182 | train_loss = 0.003811 | val_loss = 0.003808
# epoch 183 | train_loss = 0.003811 | val_loss = 0.003808
# epoch 184 | train_loss = 0.003811 | val_loss = 0.003808
# epoch 185 | train_loss = 0.003810 | val_loss = 0.003811
# epoch 186 | train_loss = 0.003810 | val_loss = 0.003808
# epoch 187 | train_loss = 0.003809 | val_loss = 0.003808
# epoch 188 | train_loss = 0.003808 | val_loss = 0.003806
# epoch 189 | train_loss = 0.003808 | val_loss = 0.003808
# epoch 190 | train_loss = 0.003809 | val_loss = 0.003805
# epoch 191 | train_loss = 0.003807 | val_loss = 0.003805
# epoch 192 | train_loss = 0.003808 | val_loss = 0.003806
# epoch 193 | train_loss = 0.003806 | val_loss = 0.003805
# epoch 194 | train_loss = 0.003807 | val_loss = 0.003805
# epoch 195 | train_loss = 0.003806 | val_loss = 0.003806
# epoch 196 | train_loss = 0.003805 | val_loss = 0.003805
# epoch 197 | train_loss = 0.003805 | val_loss = 0.003805
# epoch 198 | train_loss = 0.003805 | val_loss = 0.003803
# epoch 199 | train_loss = 0.003805 | val_loss = 0.003803
# epoch 200 | train_loss = 0.003804 | val_loss = 0.003803
# epoch 201 | train_loss = 0.003804 | val_loss = 0.003803
# epoch 202 | train_loss = 0.003803 | val_loss = 0.003802
# epoch 203 | train_loss = 0.003803 | val_loss = 0.003801
# epoch 204 | train_loss = 0.003802 | val_loss = 0.003801
# epoch 205 | train_loss = 0.003803 | val_loss = 0.003800
# epoch 206 | train_loss = 0.003802 | val_loss = 0.003800
# epoch 207 | train_loss = 0.003802 | val_loss = 0.003801
# epoch 208 | train_loss = 0.003802 | val_loss = 0.003802
# epoch 209 | train_loss = 0.003802 | val_loss = 0.003799
# epoch 210 | train_loss = 0.003801 | val_loss = 0.003798
# epoch 211 | train_loss = 0.003801 | val_loss = 0.003798
# epoch 212 | train_loss = 0.003800 | val_loss = 0.003800
# epoch 213 | train_loss = 0.003800 | val_loss = 0.003798
# epoch 214 | train_loss = 0.003799 | val_loss = 0.003799
# epoch 215 | train_loss = 0.003799 | val_loss = 0.003797
# epoch 216 | train_loss = 0.003799 | val_loss = 0.003797
# epoch 217 | train_loss = 0.003798 | val_loss = 0.003796
# epoch 218 | train_loss = 0.003799 | val_loss = 0.003796
# epoch 219 | train_loss = 0.003797 | val_loss = 0.003796
# epoch 220 | train_loss = 0.003797 | val_loss = 0.003795
# epoch 221 | train_loss = 0.003797 | val_loss = 0.003795
# epoch 222 | train_loss = 0.003797 | val_loss = 0.003794
# epoch 223 | train_loss = 0.003797 | val_loss = 0.003797
# epoch 224 | train_loss = 0.003797 | val_loss = 0.003795
# epoch 225 | train_loss = 0.003796 | val_loss = 0.003794
# epoch 226 | train_loss = 0.003796 | val_loss = 0.003797
# epoch 227 | train_loss = 0.003795 | val_loss = 0.003793
# epoch 228 | train_loss = 0.003795 | val_loss = 0.003793
# epoch 229 | train_loss = 0.003795 | val_loss = 0.003793
# epoch 230 | train_loss = 0.003795 | val_loss = 0.003794
# epoch 231 | train_loss = 0.003795 | val_loss = 0.003791
# epoch 232 | train_loss = 0.003794 | val_loss = 0.003793
# epoch 233 | train_loss = 0.003793 | val_loss = 0.003794
# epoch 234 | train_loss = 0.003793 | val_loss = 0.003791
# epoch 235 | train_loss = 0.003793 | val_loss = 0.003792
# epoch 236 | train_loss = 0.003793 | val_loss = 0.003790
# epoch 237 | train_loss = 0.003793 | val_loss = 0.003792
# epoch 238 | train_loss = 0.003793 | val_loss = 0.003792
# epoch 239 | train_loss = 0.003792 | val_loss = 0.003790
# epoch 240 | train_loss = 0.003791 | val_loss = 0.003789
# epoch 241 | train_loss = 0.003791 | val_loss = 0.003789
# epoch 242 | train_loss = 0.003791 | val_loss = 0.003788
# epoch 243 | train_loss = 0.003791 | val_loss = 0.003789
# epoch 244 | train_loss = 0.003791 | val_loss = 0.003790
# epoch 245 | train_loss = 0.003790 | val_loss = 0.003789
# epoch 246 | train_loss = 0.003790 | val_loss = 0.003792
# epoch 247 | train_loss = 0.003790 | val_loss = 0.003790
# epoch 248 | train_loss = 0.003789 | val_loss = 0.003788
# epoch 249 | train_loss = 0.003789 | val_loss = 0.003787
# epoch 250 | train_loss = 0.003789 | val_loss = 0.003787
# epoch 251 | train_loss = 0.003788 | val_loss = 0.003788
# epoch 252 | train_loss = 0.003789 | val_loss = 0.003787
# epoch 253 | train_loss = 0.003788 | val_loss = 0.003785
# epoch 254 | train_loss = 0.003787 | val_loss = 0.003786
# epoch 255 | train_loss = 0.003787 | val_loss = 0.003786
# epoch 256 | train_loss = 0.003787 | val_loss = 0.003787
# epoch 257 | train_loss = 0.003787 | val_loss = 0.003785
# epoch 258 | train_loss = 0.003787 | val_loss = 0.003785
# epoch 259 | train_loss = 0.003787 | val_loss = 0.003784
# epoch 260 | train_loss = 0.003786 | val_loss = 0.003787
# epoch 261 | train_loss = 0.003786 | val_loss = 0.003784
# epoch 262 | train_loss = 0.003785 | val_loss = 0.003784
# epoch 263 | train_loss = 0.003785 | val_loss = 0.003783
# epoch 264 | train_loss = 0.003785 | val_loss = 0.003784
# epoch 265 | train_loss = 0.003785 | val_loss = 0.003782
# epoch 266 | train_loss = 0.003784 | val_loss = 0.003784
# epoch 267 | train_loss = 0.003785 | val_loss = 0.003783
# epoch 268 | train_loss = 0.003784 | val_loss = 0.003785
# epoch 269 | train_loss = 0.003784 | val_loss = 0.003781
# epoch 270 | train_loss = 0.003783 | val_loss = 0.003782
# epoch 271 | train_loss = 0.003783 | val_loss = 0.003781
# epoch 272 | train_loss = 0.003783 | val_loss = 0.003781
# epoch 273 | train_loss = 0.003783 | val_loss = 0.003781
# epoch 274 | train_loss = 0.003782 | val_loss = 0.003781
# epoch 275 | train_loss = 0.003782 | val_loss = 0.003781
# epoch 276 | train_loss = 0.003782 | val_loss = 0.003780
# epoch 277 | train_loss = 0.003781 | val_loss = 0.003780
# epoch 278 | train_loss = 0.003781 | val_loss = 0.003780
# epoch 279 | train_loss = 0.003781 | val_loss = 0.003779
# epoch 280 | train_loss = 0.003780 | val_loss = 0.003779
# epoch 281 | train_loss = 0.003782 | val_loss = 0.003779
# epoch 282 | train_loss = 0.003780 | val_loss = 0.003779
# epoch 283 | train_loss = 0.003780 | val_loss = 0.003778
# epoch 284 | train_loss = 0.003780 | val_loss = 0.003779
# epoch 285 | train_loss = 0.003779 | val_loss = 0.003777
# epoch 286 | train_loss = 0.003779 | val_loss = 0.003778
# epoch 287 | train_loss = 0.003778 | val_loss = 0.003778
# epoch 288 | train_loss = 0.003778 | val_loss = 0.003776
# epoch 289 | train_loss = 0.003778 | val_loss = 0.003776
# epoch 290 | train_loss = 0.003779 | val_loss = 0.003777
# epoch 291 | train_loss = 0.003778 | val_loss = 0.003776
# epoch 292 | train_loss = 0.003777 | val_loss = 0.003775
# epoch 293 | train_loss = 0.003777 | val_loss = 0.003776
# epoch 294 | train_loss = 0.003776 | val_loss = 0.003775
# epoch 295 | train_loss = 0.003776 | val_loss = 0.003773
# epoch 296 | train_loss = 0.003776 | val_loss = 0.003775
# epoch 297 | train_loss = 0.003776 | val_loss = 0.003774
# epoch 298 | train_loss = 0.003776 | val_loss = 0.003774
# epoch 299 | train_loss = 0.003775 | val_loss = 0.003773
# epoch 300 | train_loss = 0.003775 | val_loss = 0.003773
# epoch 301 | train_loss = 0.003775 | val_loss = 0.003773
# epoch 302 | train_loss = 0.003775 | val_loss = 0.003773
# epoch 303 | train_loss = 0.003775 | val_loss = 0.003772
# epoch 304 | train_loss = 0.003774 | val_loss = 0.003772
# epoch 305 | train_loss = 0.003774 | val_loss = 0.003772
# epoch 306 | train_loss = 0.003773 | val_loss = 0.003771
# epoch 307 | train_loss = 0.003774 | val_loss = 0.003771
# epoch 308 | train_loss = 0.003773 | val_loss = 0.003770
# epoch 309 | train_loss = 0.003773 | val_loss = 0.003770
# epoch 310 | train_loss = 0.003772 | val_loss = 0.003770
# epoch 311 | train_loss = 0.003774 | val_loss = 0.003770
# epoch 312 | train_loss = 0.003772 | val_loss = 0.003771
# epoch 313 | train_loss = 0.003772 | val_loss = 0.003769
# epoch 314 | train_loss = 0.003771 | val_loss = 0.003769
# epoch 315 | train_loss = 0.003771 | val_loss = 0.003771
# epoch 316 | train_loss = 0.003772 | val_loss = 0.003768
# epoch 317 | train_loss = 0.003771 | val_loss = 0.003770
# epoch 318 | train_loss = 0.003771 | val_loss = 0.003771
# epoch 319 | train_loss = 0.003770 | val_loss = 0.003769
# epoch 320 | train_loss = 0.003770 | val_loss = 0.003768
# epoch 321 | train_loss = 0.003770 | val_loss = 0.003767
# epoch 322 | train_loss = 0.003769 | val_loss = 0.003768
# epoch 323 | train_loss = 0.003769 | val_loss = 0.003769
# epoch 324 | train_loss = 0.003769 | val_loss = 0.003771
# epoch 325 | train_loss = 0.003769 | val_loss = 0.003768
# epoch 326 | train_loss = 0.003769 | val_loss = 0.003767
# epoch 327 | train_loss = 0.003768 | val_loss = 0.003766
# epoch 328 | train_loss = 0.003768 | val_loss = 0.003767
# epoch 329 | train_loss = 0.003768 | val_loss = 0.003767
# epoch 330 | train_loss = 0.003768 | val_loss = 0.003765
# epoch 331 | train_loss = 0.003767 | val_loss = 0.003765
# epoch 332 | train_loss = 0.003769 | val_loss = 0.003765
# epoch 333 | train_loss = 0.003767 | val_loss = 0.003764
# epoch 334 | train_loss = 0.003767 | val_loss = 0.003764
# epoch 335 | train_loss = 0.003766 | val_loss = 0.003765
# epoch 336 | train_loss = 0.003768 | val_loss = 0.003765
# epoch 337 | train_loss = 0.003766 | val_loss = 0.003765
# epoch 338 | train_loss = 0.003766 | val_loss = 0.003763
# epoch 339 | train_loss = 0.003765 | val_loss = 0.003766
# epoch 340 | train_loss = 0.003766 | val_loss = 0.003763
# epoch 341 | train_loss = 0.003766 | val_loss = 0.003764
# epoch 342 | train_loss = 0.003765 | val_loss = 0.003763
# epoch 343 | train_loss = 0.003765 | val_loss = 0.003763
# epoch 344 | train_loss = 0.003764 | val_loss = 0.003764
# epoch 345 | train_loss = 0.003764 | val_loss = 0.003764
# epoch 346 | train_loss = 0.003765 | val_loss = 0.003761
# epoch 347 | train_loss = 0.003764 | val_loss = 0.003763
# epoch 348 | train_loss = 0.003765 | val_loss = 0.003762
# epoch 349 | train_loss = 0.003763 | val_loss = 0.003762
# epoch 350 | train_loss = 0.003763 | val_loss = 0.003760
# epoch 351 | train_loss = 0.003763 | val_loss = 0.003761
# epoch 352 | train_loss = 0.003762 | val_loss = 0.003760
# epoch 353 | train_loss = 0.003762 | val_loss = 0.003760
# epoch 354 | train_loss = 0.003762 | val_loss = 0.003759
# epoch 355 | train_loss = 0.003762 | val_loss = 0.003762
# epoch 356 | train_loss = 0.003763 | val_loss = 0.003761
# epoch 357 | train_loss = 0.003761 | val_loss = 0.003758
# epoch 358 | train_loss = 0.003762 | val_loss = 0.003760
# epoch 359 | train_loss = 0.003761 | val_loss = 0.003759
# epoch 360 | train_loss = 0.003762 | val_loss = 0.003759
# epoch 361 | train_loss = 0.003761 | val_loss = 0.003758
# epoch 362 | train_loss = 0.003760 | val_loss = 0.003759
# epoch 363 | train_loss = 0.003760 | val_loss = 0.003758
# epoch 364 | train_loss = 0.003760 | val_loss = 0.003757
# epoch 365 | train_loss = 0.003761 | val_loss = 0.003758
# epoch 366 | train_loss = 0.003760 | val_loss = 0.003759
# epoch 367 | train_loss = 0.003760 | val_loss = 0.003757
# epoch 368 | train_loss = 0.003759 | val_loss = 0.003759
# epoch 369 | train_loss = 0.003760 | val_loss = 0.003758
# epoch 370 | train_loss = 0.003759 | val_loss = 0.003757
# epoch 371 | train_loss = 0.003758 | val_loss = 0.003756
# epoch 372 | train_loss = 0.003759 | val_loss = 0.003757
# epoch 373 | train_loss = 0.003759 | val_loss = 0.003760
# epoch 374 | train_loss = 0.003759 | val_loss = 0.003755
# epoch 375 | train_loss = 0.003758 | val_loss = 0.003756
# epoch 376 | train_loss = 0.003757 | val_loss = 0.003757
# epoch 377 | train_loss = 0.003758 | val_loss = 0.003755
# epoch 378 | train_loss = 0.003757 | val_loss = 0.003756
# epoch 379 | train_loss = 0.003757 | val_loss = 0.003755
# epoch 380 | train_loss = 0.003757 | val_loss = 0.003757
# epoch 381 | train_loss = 0.003757 | val_loss = 0.003761
# epoch 382 | train_loss = 0.003758 | val_loss = 0.003756
# epoch 383 | train_loss = 0.003757 | val_loss = 0.003753
# epoch 384 | train_loss = 0.003756 | val_loss = 0.003753
# epoch 385 | train_loss = 0.003756 | val_loss = 0.003754
# epoch 386 | train_loss = 0.003756 | val_loss = 0.003753
# epoch 387 | train_loss = 0.003756 | val_loss = 0.003757
# epoch 388 | train_loss = 0.003755 | val_loss = 0.003753
# epoch 389 | train_loss = 0.003755 | val_loss = 0.003753
# epoch 390 | train_loss = 0.003755 | val_loss = 0.003753
# epoch 391 | train_loss = 0.003755 | val_loss = 0.003752
# epoch 392 | train_loss = 0.003755 | val_loss = 0.003753
# epoch 393 | train_loss = 0.003755 | val_loss = 0.003752
# epoch 394 | train_loss = 0.003754 | val_loss = 0.003756
# epoch 395 | train_loss = 0.003755 | val_loss = 0.003751
# epoch 396 | train_loss = 0.003754 | val_loss = 0.003751
# epoch 397 | train_loss = 0.003754 | val_loss = 0.003754
# epoch 398 | train_loss = 0.003754 | val_loss = 0.003752
# epoch 399 | train_loss = 0.003753 | val_loss = 0.003750
# epoch 400 | train_loss = 0.003754 | val_loss = 0.003751
# [TRAINED ERROR | SRCNN_SmCL] test_MAE=0.003752 | test_RMSE=0.007133

# %% [markdown]
# ### Check for physical violations

# %%
# Load ranges for denormalising
RANGES_PATH = Path.cwd() / "ranges.py"
ns = runpy.run_path(str(RANGES_PATH))
RANGES = ns["RANGES"]

vmin = float(RANGES[variable][0])
vmax = float(RANGES[variable][1])

# Which variables have to be non-negative in physical units?
NONNEG_VARS = {
    "2m_temperature",
    "mean_surface_downward_long_wave_radiation_flux",
    "mean_surface_downward_short_wave_radiation_flux",
    "specific_humidity",
    "surface_pressure",
    "total_precipitation",
}
need_nonneg = (variable in NONNEG_VARS)

# Helper for calculating reduction percentages
def calculate_reduction(b, t):
    if b is None or t is None:
        return None
    b = float(b)
    t = float(t)
    if not math.isfinite(b) or not math.isfinite(t):
        return None
    if b == 0.0:
        return 0.0 if t == 0.0 else None
    return 100.0 * (b - t) / b

#=========================================================================================#

# Calculate the baseline violations and add to report
negative_pixels_total = 0
total_pixels = 0

mse_sum = 0.0
mse_count = 0

with torch.no_grad():
    for x, _ in test_loader:
        x = x.to(device, non_blocking=True)

        pred = x

        pred_phys = pred * (vmax - vmin) + vmin
        x_phys    = x    * (vmax - vmin) + vmin

        if need_nonneg:
            negative_pixels_total += (pred_phys < 0).sum().item()
            total_pixels += pred_phys.numel()

        pred_lr = F.avg_pool2d(pred_phys, kernel_size=2, stride=2)
        x_lr    = F.avg_pool2d(x_phys,    kernel_size=2, stride=2)

        diff = pred_lr - x_lr
        mse_sum += (diff * diff).sum().item()
        mse_count += diff.numel()

baseline_mean_consistency_rmse = float(math.sqrt(mse_sum / max(mse_count, 1)))
baseline_negatives_per_million = 1000000*(float(negative_pixels_total/max(total_pixels, 1))) if need_nonneg else None
    
bpm_str = f"{baseline_negatives_per_million:.6f}" if baseline_negatives_per_million is not None else "NA"
print(f"[BASELINE VIOLATION | IDENTITY MODEL] mean_consistency_rmse = {baseline_mean_consistency_rmse:.6f} | negatives_per_million = {bpm_str}")
    
report["baseline_violation"] = {
    "mean_consistency_rmse": baseline_mean_consistency_rmse,
    "negatives_per_million": baseline_negatives_per_million,
}

#=========================================================================================#

# Load the best checkpoint and evaluate violations of the test set
ckpt_path_best = run_dir / "best_model.pt"
ckpt = torch.load(ckpt_path_best, map_location=device)
model.load_state_dict(ckpt["state_dict"])
model.to(device)
model.eval()

# Calculate the trained violations and add to report
negative_pixels_total = 0
total_pixels = 0

mse_sum = 0.0
mse_count = 0

model.eval()
with torch.no_grad():
    for x, _ in test_loader:
        x = x.to(device, non_blocking=True)

        pred = model(x)

        pred_phys = pred * (vmax - vmin) + vmin
        x_phys    = x    * (vmax - vmin) + vmin

        if need_nonneg:
            negative_pixels_total += (pred_phys < 0).sum().item()
            total_pixels += pred_phys.numel()

        pred_lr = F.avg_pool2d(pred_phys, kernel_size=2, stride=2)
        x_lr    = F.avg_pool2d(x_phys,    kernel_size=2, stride=2)

        diff = pred_lr - x_lr
        mse_sum += (diff * diff).sum().item()
        mse_count += diff.numel()

trained_mean_consistency_rmse = float(math.sqrt(mse_sum / max(mse_count, 1)))
trained_negatives_per_million = 1000000*(float(negative_pixels_total/max(total_pixels, 1))) if need_nonneg else None
    
tpm_str = f"{trained_negatives_per_million:.6f}" if trained_negatives_per_million is not None else "NA"
print(f"[TRAINED VIOLATION | SRCNN_SmCL] mean_consistency_rmse = {trained_mean_consistency_rmse:.6f} | negatives_per_million = {tpm_str}")
    
report["trained_violation"] = {
    "mean_consistency_rmse": trained_mean_consistency_rmse,
    "negatives_per_million": trained_negatives_per_million,
}

#=========================================================================================#

# Calculate how much the model performace improved
report["violation_reduction"] = {
    "mean_consistency_rmse": calculate_reduction(baseline_mean_consistency_rmse, trained_mean_consistency_rmse),
    "negatives_per_million": calculate_reduction(baseline_negatives_per_million, trained_negatives_per_million),
}

# Save the whole report in the working directory
def scrub_json(x):
    if isinstance(x, float):
        return None if (math.isnan(x) or math.isinf(x)) else x
    if isinstance(x, dict):
        return {k: scrub_json(v) for k, v in x.items()}
    if isinstance(x, list):
        return [scrub_json(v) for v in x]
    return x

with open(report_path, "w", encoding="utf-8") as f:
    json.dump(scrub_json(report), f, indent=2, sort_keys=False, allow_nan=False)
# Out:
# [BASELINE VIOLATION | IDENTITY MODEL] mean_consistency_rmse = 0.000000 | negatives_per_million = 0.000000
# [TRAINED VIOLATION | SRCNN_SmCL] mean_consistency_rmse = 0.000014 | negatives_per_million = 0.000000
