# %% [markdown]
# ### Packages + Configuration

# %%
import gc
import json
import math
import runpy
from pathlib import Path

import numpy as np

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

years = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
variable  = "2m_temperature"

seed = 0

epochs = 400
lr = 1e-4
batch_size = 32
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
pin_memory = (device.type == "cuda")

dataset_dir = Path.cwd() / "input_labels"

# %% [markdown]
# ### Load data and check if normalized

# %%
def to_nchw(a: np.ndarray) -> np.ndarray:
    a = np.asarray(a)
    if a.ndim == 3:
        a = a[:, None, :, :]
    elif a.ndim == 4:
        if a.shape[1] in (1, 3):
            pass
        elif a.shape[-1] in (1, 3):
            a = a.transpose(0, 3, 1, 2)
    return a.astype(np.float32)

files = []
for year in years:
    files.append(dataset_dir / f"{variable}" / f"{year}_{variable}.npz")

N = 0
C = H = W = None
for file in files:
    with np.load(file) as data:
        X0 = to_nchw(data["X"])
        if C is None:
            _, C, H, W = X0.shape
        N += X0.shape[0]
        del X0
gc.collect()

X = np.empty((N, C, H, W), dtype=np.float32)
Y = np.empty((N, C, H, W), dtype=np.float32)

offset = 0
for file in files:
    with np.load(file) as data:
        X0 = to_nchw(data["X"])
        Y0 = to_nchw(data["Y"])
    n0 = X0.shape[0]
    X[offset:offset+n0] = X0
    Y[offset:offset+n0] = Y0
    offset += n0
    del X0, Y0
gc.collect()

def check_0_1(name: str, a: np.ndarray, tol: float = 1e-6):
    amin = float(np.nanmin(a))
    amax = float(np.nanmax(a))
    ok = (amin >= -tol) and (amax <= 1.0 + tol)
    if ok:
        print(f"The data is properly normalized: min = {amin:.6f}, max = {amax:.6f}")
    if not ok:
        raise ValueError(
            print(f"The normalization step is missing or inconsistent: min = {amin:.6f}, max = {amax:.6f}")
        )

check_0_1("X", X)
check_0_1("Y", Y)

np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

n = len(X)
train_n = int(0.8 * n)
val_n = int(0.1 * n)

rng = np.random.default_rng(seed)
perm = rng.permutation(n)

train_idx = perm[:train_n]
val_idx   = perm[train_n:train_n + val_n]
test_idx  = perm[train_n + val_n:]
# Out:
# The data is properly normalized: min = 0.010022, max = 0.988940
# The data is properly normalized: min = 0.000000, max = 1.000000

# %% [markdown]
# ### Prepare data

# %%
class FullDataset(Dataset):
    def __init__(self, X, Y, indices):
        self.X = X
        self.Y = Y
        self.indices = np.asarray(indices)

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, i):
        idx = self.indices[i]
        return torch.from_numpy(self.X[idx]), torch.from_numpy(self.Y[idx])
        
train_ds = FullDataset(X, Y, train_idx)
val_ds   = FullDataset(X, Y, val_idx)
test_ds  = FullDataset(X, Y, test_idx)

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True,  num_workers=0, pin_memory=pin_memory)
val_loader   = DataLoader(val_ds,   batch_size=1,          shuffle=False, num_workers=0, pin_memory=pin_memory)
test_loader  = DataLoader(test_ds,  batch_size=1,          shuffle=False, num_workers=0, pin_memory=pin_memory)

# %% [markdown]
# ### Model + Evaluators

# %%
# simple SRCNN
class SRCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 64, kernel_size=9, padding=4)
        self.conv2 = nn.Conv2d(64, 32, kernel_size=1, padding=0)
        self.conv3 = nn.Conv2d(32, 1, kernel_size=5, padding=2)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        return self.conv3(x)

# metric for evaluating "on the run"
@torch.no_grad()
def eval_loss(loader, model, device):
    model.eval()
    total_loss = 0.0
    n = 0

    for x, y in loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        pred = model(x)
        total_loss += F.l1_loss(pred, y, reduction="sum").item()
        n += y.numel()

    return total_loss / max(n, 1)

# Metric for final test set evaluation
@torch.no_grad()
def eval_mae_rmse(loader, model, device, baseline: bool = False):
    model.eval()
    abs_sum = 0.0
    sq_sum = 0.0
    n = 0

    for x, y in loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        pred = x if baseline else model(x)

        diff = pred - y
        abs_sum += diff.abs().sum().item()
        sq_sum  += (diff * diff).sum().item()
        n += y.numel()

    mae = abs_sum / max(n, 1)
    rmse = math.sqrt(sq_sum / max(n, 1))
    return mae, rmse

# define model
model = SRCNN().to(device)

# %% [markdown]
# ### Training Loop

# %%
# Create a path where we will store current run data
run_dir = Path("runs") / f"SRCNN_{variable}" 
run_dir.mkdir(parents=True, exist_ok=True)

# Path for report.json what will store important information about the run
report_path = run_dir / "report.json"

# Fill in the training configuration (these don't depend on post-training data)
report = {
    "config": {
        "model": "SRCNN",
        "years": years,
        "variable": variable,

        "seed": seed,
        
        "epochs": epochs,
        "lr": lr,
        "batch_size": batch_size,
        "device": str(device),
    }
}

#=========================================================================================#

def train():
    opt = torch.optim.Adam(model.parameters(), lr=lr)

    # Store intermediate losses for plotting later
    train_hist = []
    val_hist = []
    epoch_hist = []

    # Here we will store the best checkpoint
    best_val = float("inf")
    ckpt_path_best = run_dir / "best_model.pt"

    #=========================================================================================#
    
    # Calculate the baseline metrics and add to report
    baseline_mae, baseline_rmse = eval_mae_rmse(test_loader, model, device, baseline=True)
    
    print(f"[BASELINE ERROR | IDENTITY MODEL] test_MAE={baseline_mae:.6f} | test_RMSE={baseline_rmse:.6f}")
    
    report["baseline_error"] = {
        "mae": baseline_mae,
        "rmse": baseline_rmse,
    }

    #=========================================================================================#
    
    # Start iterating across epochs
    for epoch in range(1, epochs + 1):
        model.train()
        total_train_loss = 0.0
        n = 0

        for x, y in train_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            opt.zero_grad(set_to_none=True)
            pred = model(x)
            loss = F.l1_loss(pred, y)

            loss.backward()
            opt.step()

            loss = F.l1_loss(pred, y, reduction="sum")
            total_train_loss += loss.item()
            n += y.numel()

        train_loss = total_train_loss / max(n, 1)
        val_loss = eval_loss(val_loader, model, device)

        print(f"epoch {epoch:03d} | train_loss = {train_loss:.6f} | val_loss = {val_loss:.6f}")

        epoch_hist.append(epoch)
        train_hist.append(train_loss)
        val_hist.append(val_loss)

        if val_loss < best_val:
            best_val = val_loss
            torch.save(
                {"state_dict": model.state_dict(), "best_val": best_val, "epoch": epoch},
                ckpt_path_best,
            )

    #=========================================================================================#
    
    # Plot the saved train and val losses saved during training
    fig, ax = plt.subplots(figsize=(7, 4), constrained_layout=True)
    ax.plot(epoch_hist, train_hist, label="train_loss")
    ax.plot(epoch_hist, val_hist, label="val_loss")
    ax.set_xlabel("epoch")
    ax.set_ylabel("loss")
    ax.set_title("Loss curve")
    ax.grid(True, alpha=0.3)
    ax.legend()
    fig.savefig(run_dir / f"SRCNN_{variable}_loss_curve.png", dpi=150)
    plt.close(fig)

    #=========================================================================================#
    
    # Load the best checkpoint and evaluate it on the test set
    if ckpt_path_best.exists():
        ckpt = torch.load(ckpt_path_best, map_location=device)
        model.load_state_dict(ckpt["state_dict"])

    # Calculate the trained metrics and add to report
    test_mae, test_rmse = eval_mae_rmse(test_loader, model, device, baseline=False)
    
    print(f"[TRAINED ERROR | SRCNN] test_MAE={test_mae:.6f} | test_RMSE={test_rmse:.6f}")

    report["trained_error"] = {
        "mae": test_mae,
        "rmse": test_rmse,
    }

    #=========================================================================================#
    
    # Calculate how much the model performace improved
    report["error_reduction"] = {
        "mae": 100.0 * (baseline_mae - test_mae) / baseline_mae if baseline_mae != 0 else float("nan"),
        "rmse": 100.0 * (baseline_rmse - test_rmse) / baseline_rmse if baseline_rmse != 0 else float("nan"),
    }

if __name__ == "__main__":
    train()
# Out:
# [BASELINE ERROR | IDENTITY MODEL] test_MAE=0.005972 | test_RMSE=0.010435
# epoch 001 | train_loss = 0.282859 | val_loss = 0.020945
# epoch 002 | train_loss = 0.018620 | val_loss = 0.015565
# epoch 003 | train_loss = 0.013072 | val_loss = 0.011412
# epoch 004 | train_loss = 0.010621 | val_loss = 0.009618
# epoch 005 | train_loss = 0.008865 | val_loss = 0.008799
# epoch 006 | train_loss = 0.007682 | val_loss = 0.007236
# epoch 007 | train_loss = 0.006998 | val_loss = 0.006759
# epoch 008 | train_loss = 0.006610 | val_loss = 0.006519
# epoch 009 | train_loss = 0.006429 | val_loss = 0.006340
# epoch 010 | train_loss = 0.006319 | val_loss = 0.006213
# epoch 011 | train_loss = 0.006206 | val_loss = 0.006280
# epoch 012 | train_loss = 0.006154 | val_loss = 0.006189
# epoch 013 | train_loss = 0.006126 | val_loss = 0.006099
# epoch 014 | train_loss = 0.006064 | val_loss = 0.006042
# epoch 015 | train_loss = 0.005966 | val_loss = 0.005983
# epoch 016 | train_loss = 0.005942 | val_loss = 0.005881
# epoch 017 | train_loss = 0.005882 | val_loss = 0.005915
# epoch 018 | train_loss = 0.005863 | val_loss = 0.005864
# epoch 019 | train_loss = 0.005781 | val_loss = 0.005842
# epoch 020 | train_loss = 0.005786 | val_loss = 0.005776
# epoch 021 | train_loss = 0.005769 | val_loss = 0.005631
# epoch 022 | train_loss = 0.005710 | val_loss = 0.005680
# epoch 023 | train_loss = 0.005657 | val_loss = 0.005754
# epoch 024 | train_loss = 0.005644 | val_loss = 0.005615
# epoch 025 | train_loss = 0.005640 | val_loss = 0.005618
# epoch 026 | train_loss = 0.005588 | val_loss = 0.005649
# epoch 027 | train_loss = 0.005552 | val_loss = 0.005762
# epoch 028 | train_loss = 0.005557 | val_loss = 0.005530
# epoch 029 | train_loss = 0.005561 | val_loss = 0.005491
# epoch 030 | train_loss = 0.005567 | val_loss = 0.005506
# epoch 031 | train_loss = 0.005586 | val_loss = 0.005476
# epoch 032 | train_loss = 0.005462 | val_loss = 0.005468
# epoch 033 | train_loss = 0.005421 | val_loss = 0.005435
# epoch 034 | train_loss = 0.005411 | val_loss = 0.005448
# epoch 035 | train_loss = 0.005404 | val_loss = 0.005438
# epoch 036 | train_loss = 0.005365 | val_loss = 0.005401
# epoch 037 | train_loss = 0.005378 | val_loss = 0.005397
# epoch 038 | train_loss = 0.005358 | val_loss = 0.005346
# epoch 039 | train_loss = 0.005351 | val_loss = 0.005360
# epoch 040 | train_loss = 0.005315 | val_loss = 0.005337
# epoch 041 | train_loss = 0.005339 | val_loss = 0.005278
# epoch 042 | train_loss = 0.005252 | val_loss = 0.005259
# epoch 043 | train_loss = 0.005313 | val_loss = 0.005269
# epoch 044 | train_loss = 0.005256 | val_loss = 0.005303
# epoch 045 | train_loss = 0.005280 | val_loss = 0.005371
# epoch 046 | train_loss = 0.005263 | val_loss = 0.005301
# epoch 047 | train_loss = 0.005296 | val_loss = 0.005289
# epoch 048 | train_loss = 0.005298 | val_loss = 0.005204
# epoch 049 | train_loss = 0.005248 | val_loss = 0.005173
# epoch 050 | train_loss = 0.005238 | val_loss = 0.005210
# epoch 051 | train_loss = 0.005201 | val_loss = 0.005088
# epoch 052 | train_loss = 0.005184 | val_loss = 0.005160
# epoch 053 | train_loss = 0.005172 | val_loss = 0.005148
# epoch 054 | train_loss = 0.005142 | val_loss = 0.005151
# epoch 055 | train_loss = 0.005188 | val_loss = 0.005067
# epoch 056 | train_loss = 0.005140 | val_loss = 0.005183
# epoch 057 | train_loss = 0.005130 | val_loss = 0.005096
# epoch 058 | train_loss = 0.005115 | val_loss = 0.005135
# epoch 059 | train_loss = 0.005107 | val_loss = 0.005113
# epoch 060 | train_loss = 0.005096 | val_loss = 0.005187
# epoch 061 | train_loss = 0.005103 | val_loss = 0.005138
# epoch 062 | train_loss = 0.005147 | val_loss = 0.005070
# epoch 063 | train_loss = 0.005153 | val_loss = 0.005121
# epoch 064 | train_loss = 0.005104 | val_loss = 0.005025
# epoch 065 | train_loss = 0.005084 | val_loss = 0.005069
# epoch 066 | train_loss = 0.005055 | val_loss = 0.005041
# epoch 067 | train_loss = 0.005008 | val_loss = 0.004973
# epoch 068 | train_loss = 0.005031 | val_loss = 0.005001
# epoch 069 | train_loss = 0.005042 | val_loss = 0.005104
# epoch 070 | train_loss = 0.005043 | val_loss = 0.005065
# epoch 071 | train_loss = 0.005042 | val_loss = 0.005047
# epoch 072 | train_loss = 0.005042 | val_loss = 0.005040
# epoch 073 | train_loss = 0.004992 | val_loss = 0.004996
# epoch 074 | train_loss = 0.004999 | val_loss = 0.005036
# epoch 075 | train_loss = 0.005026 | val_loss = 0.005000
# epoch 076 | train_loss = 0.004990 | val_loss = 0.004962
# epoch 077 | train_loss = 0.005015 | val_loss = 0.004918
# epoch 078 | train_loss = 0.005011 | val_loss = 0.004972
# epoch 079 | train_loss = 0.004998 | val_loss = 0.004933
# epoch 080 | train_loss = 0.004969 | val_loss = 0.004948
# epoch 081 | train_loss = 0.004958 | val_loss = 0.004960
# epoch 082 | train_loss = 0.004964 | val_loss = 0.004887
# epoch 083 | train_loss = 0.004975 | val_loss = 0.004971
# epoch 084 | train_loss = 0.004990 | val_loss = 0.004996
# epoch 085 | train_loss = 0.004959 | val_loss = 0.004941
# epoch 086 | train_loss = 0.004936 | val_loss = 0.004873
# epoch 087 | train_loss = 0.004958 | val_loss = 0.004947
# epoch 088 | train_loss = 0.004933 | val_loss = 0.004997
# epoch 089 | train_loss = 0.004934 | val_loss = 0.004929
# epoch 090 | train_loss = 0.004926 | val_loss = 0.004820
# epoch 091 | train_loss = 0.004910 | val_loss = 0.004852
# epoch 092 | train_loss = 0.004909 | val_loss = 0.004856
# epoch 093 | train_loss = 0.004926 | val_loss = 0.004837
# epoch 094 | train_loss = 0.004908 | val_loss = 0.004943
# epoch 095 | train_loss = 0.004994 | val_loss = 0.004888
# epoch 096 | train_loss = 0.004926 | val_loss = 0.004798
# epoch 097 | train_loss = 0.004895 | val_loss = 0.004968
# epoch 098 | train_loss = 0.004938 | val_loss = 0.004900
# epoch 099 | train_loss = 0.004896 | val_loss = 0.004831
# epoch 100 | train_loss = 0.004912 | val_loss = 0.004834
# epoch 101 | train_loss = 0.004892 | val_loss = 0.004844
# epoch 102 | train_loss = 0.004872 | val_loss = 0.004823
# epoch 103 | train_loss = 0.004844 | val_loss = 0.004852
# epoch 104 | train_loss = 0.004856 | val_loss = 0.004835
# epoch 105 | train_loss = 0.004836 | val_loss = 0.004877
# epoch 106 | train_loss = 0.004865 | val_loss = 0.004925
# epoch 107 | train_loss = 0.004847 | val_loss = 0.004896
# epoch 108 | train_loss = 0.004827 | val_loss = 0.004924
# epoch 109 | train_loss = 0.004853 | val_loss = 0.004839
# epoch 110 | train_loss = 0.004840 | val_loss = 0.004785
# epoch 111 | train_loss = 0.004852 | val_loss = 0.004903
# epoch 112 | train_loss = 0.004864 | val_loss = 0.004774
# epoch 113 | train_loss = 0.004858 | val_loss = 0.004815
# epoch 114 | train_loss = 0.004813 | val_loss = 0.004838
# epoch 115 | train_loss = 0.004820 | val_loss = 0.004840
# epoch 116 | train_loss = 0.004833 | val_loss = 0.004761
# epoch 117 | train_loss = 0.004832 | val_loss = 0.004838
# epoch 118 | train_loss = 0.004843 | val_loss = 0.004771
# epoch 119 | train_loss = 0.004767 | val_loss = 0.004774
# epoch 120 | train_loss = 0.004790 | val_loss = 0.004767
# epoch 121 | train_loss = 0.004783 | val_loss = 0.004779
# epoch 122 | train_loss = 0.004809 | val_loss = 0.004800
# epoch 123 | train_loss = 0.004827 | val_loss = 0.004731
# epoch 124 | train_loss = 0.004778 | val_loss = 0.004734
# epoch 125 | train_loss = 0.004789 | val_loss = 0.004757
# epoch 126 | train_loss = 0.004766 | val_loss = 0.004813
# epoch 127 | train_loss = 0.004760 | val_loss = 0.004826
# epoch 128 | train_loss = 0.004758 | val_loss = 0.004818
# epoch 129 | train_loss = 0.004776 | val_loss = 0.004833
# epoch 130 | train_loss = 0.004836 | val_loss = 0.004726
# epoch 131 | train_loss = 0.004745 | val_loss = 0.004703
# epoch 132 | train_loss = 0.004733 | val_loss = 0.004698
# epoch 133 | train_loss = 0.004807 | val_loss = 0.004742
# epoch 134 | train_loss = 0.004837 | val_loss = 0.004786
# epoch 135 | train_loss = 0.004772 | val_loss = 0.004747
# epoch 136 | train_loss = 0.004756 | val_loss = 0.004752
# epoch 137 | train_loss = 0.004738 | val_loss = 0.004842
# epoch 138 | train_loss = 0.004722 | val_loss = 0.004793
# epoch 139 | train_loss = 0.004769 | val_loss = 0.004714
# epoch 140 | train_loss = 0.004741 | val_loss = 0.004793
# epoch 141 | train_loss = 0.004737 | val_loss = 0.004737
# epoch 142 | train_loss = 0.004719 | val_loss = 0.004737
# epoch 143 | train_loss = 0.004728 | val_loss = 0.004717
# epoch 144 | train_loss = 0.004703 | val_loss = 0.004724
# epoch 145 | train_loss = 0.004681 | val_loss = 0.004790
# epoch 146 | train_loss = 0.004712 | val_loss = 0.004692
# epoch 147 | train_loss = 0.004758 | val_loss = 0.004712
# epoch 148 | train_loss = 0.004763 | val_loss = 0.004711
# epoch 149 | train_loss = 0.004734 | val_loss = 0.004643
# epoch 150 | train_loss = 0.004694 | val_loss = 0.004684
# epoch 151 | train_loss = 0.004693 | val_loss = 0.004714
# epoch 152 | train_loss = 0.004695 | val_loss = 0.004767
# epoch 153 | train_loss = 0.004674 | val_loss = 0.004697
# epoch 154 | train_loss = 0.004678 | val_loss = 0.004714
# epoch 155 | train_loss = 0.004698 | val_loss = 0.004660
# epoch 156 | train_loss = 0.004671 | val_loss = 0.004776
# epoch 157 | train_loss = 0.004668 | val_loss = 0.004706
# epoch 158 | train_loss = 0.004697 | val_loss = 0.004701
# epoch 159 | train_loss = 0.004694 | val_loss = 0.004683
# epoch 160 | train_loss = 0.004660 | val_loss = 0.004650
# epoch 161 | train_loss = 0.004674 | val_loss = 0.004584
# epoch 162 | train_loss = 0.004680 | val_loss = 0.004636
# epoch 163 | train_loss = 0.004689 | val_loss = 0.004669
# epoch 164 | train_loss = 0.004641 | val_loss = 0.004617
# epoch 165 | train_loss = 0.004634 | val_loss = 0.004678
# epoch 166 | train_loss = 0.004655 | val_loss = 0.004604
# epoch 167 | train_loss = 0.004644 | val_loss = 0.004604
# epoch 168 | train_loss = 0.004633 | val_loss = 0.004591
# epoch 169 | train_loss = 0.004682 | val_loss = 0.004554
# epoch 170 | train_loss = 0.004608 | val_loss = 0.004634
# epoch 171 | train_loss = 0.004624 | val_loss = 0.004571
# epoch 172 | train_loss = 0.004631 | val_loss = 0.004580
# epoch 173 | train_loss = 0.004650 | val_loss = 0.004492
# epoch 174 | train_loss = 0.004524 | val_loss = 0.004592
# epoch 175 | train_loss = 0.004595 | val_loss = 0.004613
# epoch 176 | train_loss = 0.004644 | val_loss = 0.004652
# epoch 177 | train_loss = 0.004604 | val_loss = 0.004605
# epoch 178 | train_loss = 0.004567 | val_loss = 0.004541
# epoch 179 | train_loss = 0.004565 | val_loss = 0.004598
# epoch 180 | train_loss = 0.004589 | val_loss = 0.004572
# epoch 181 | train_loss = 0.004593 | val_loss = 0.004491
# epoch 182 | train_loss = 0.004580 | val_loss = 0.004564
# epoch 183 | train_loss = 0.004553 | val_loss = 0.004591
# epoch 184 | train_loss = 0.004580 | val_loss = 0.004544
# epoch 185 | train_loss = 0.004572 | val_loss = 0.004471
# epoch 186 | train_loss = 0.004533 | val_loss = 0.004661
# epoch 187 | train_loss = 0.004552 | val_loss = 0.004598
# epoch 188 | train_loss = 0.004574 | val_loss = 0.004572
# epoch 189 | train_loss = 0.004568 | val_loss = 0.004623
# epoch 190 | train_loss = 0.004553 | val_loss = 0.004588
# epoch 191 | train_loss = 0.004569 | val_loss = 0.004552
# epoch 192 | train_loss = 0.004522 | val_loss = 0.004600
# epoch 193 | train_loss = 0.004549 | val_loss = 0.004569
# epoch 194 | train_loss = 0.004565 | val_loss = 0.004488
# epoch 195 | train_loss = 0.004527 | val_loss = 0.004539
# epoch 196 | train_loss = 0.004503 | val_loss = 0.004499
# epoch 197 | train_loss = 0.004530 | val_loss = 0.004478
# epoch 198 | train_loss = 0.004584 | val_loss = 0.004514
# epoch 199 | train_loss = 0.004555 | val_loss = 0.004476
# epoch 200 | train_loss = 0.004528 | val_loss = 0.004434
# epoch 201 | train_loss = 0.004500 | val_loss = 0.004500
# epoch 202 | train_loss = 0.004488 | val_loss = 0.004476
# epoch 203 | train_loss = 0.004474 | val_loss = 0.004447
# epoch 204 | train_loss = 0.004465 | val_loss = 0.004438
# epoch 205 | train_loss = 0.004504 | val_loss = 0.004453
# epoch 206 | train_loss = 0.004504 | val_loss = 0.004514
# epoch 207 | train_loss = 0.004505 | val_loss = 0.004500
# epoch 208 | train_loss = 0.004497 | val_loss = 0.004459
# epoch 209 | train_loss = 0.004466 | val_loss = 0.004475
# epoch 210 | train_loss = 0.004459 | val_loss = 0.004491
# epoch 211 | train_loss = 0.004496 | val_loss = 0.004509
# epoch 212 | train_loss = 0.004503 | val_loss = 0.004457
# epoch 213 | train_loss = 0.004508 | val_loss = 0.004467
# epoch 214 | train_loss = 0.004475 | val_loss = 0.004397
# epoch 215 | train_loss = 0.004473 | val_loss = 0.004468
# epoch 216 | train_loss = 0.004463 | val_loss = 0.004407
# epoch 217 | train_loss = 0.004453 | val_loss = 0.004421
# epoch 218 | train_loss = 0.004457 | val_loss = 0.004415
# epoch 219 | train_loss = 0.004501 | val_loss = 0.004410
# epoch 220 | train_loss = 0.004452 | val_loss = 0.004411
# epoch 221 | train_loss = 0.004457 | val_loss = 0.004455
# epoch 222 | train_loss = 0.004467 | val_loss = 0.004412
# epoch 223 | train_loss = 0.004478 | val_loss = 0.004420
# epoch 224 | train_loss = 0.004441 | val_loss = 0.004419
# epoch 225 | train_loss = 0.004431 | val_loss = 0.004468
# epoch 226 | train_loss = 0.004463 | val_loss = 0.004366
# epoch 227 | train_loss = 0.004448 | val_loss = 0.004454
# epoch 228 | train_loss = 0.004435 | val_loss = 0.004434
# epoch 229 | train_loss = 0.004410 | val_loss = 0.004429
# epoch 230 | train_loss = 0.004413 | val_loss = 0.004411
# epoch 231 | train_loss = 0.004439 | val_loss = 0.004393
# epoch 232 | train_loss = 0.004455 | val_loss = 0.004391
# epoch 233 | train_loss = 0.004459 | val_loss = 0.004420
# epoch 234 | train_loss = 0.004406 | val_loss = 0.004365
# epoch 235 | train_loss = 0.004407 | val_loss = 0.004405
# epoch 236 | train_loss = 0.004416 | val_loss = 0.004340
# epoch 237 | train_loss = 0.004390 | val_loss = 0.004416
# epoch 238 | train_loss = 0.004405 | val_loss = 0.004422
# epoch 239 | train_loss = 0.004393 | val_loss = 0.004303
# epoch 240 | train_loss = 0.004389 | val_loss = 0.004343
# epoch 241 | train_loss = 0.004402 | val_loss = 0.004339
# epoch 242 | train_loss = 0.004422 | val_loss = 0.004331
# epoch 243 | train_loss = 0.004419 | val_loss = 0.004331
# epoch 244 | train_loss = 0.004425 | val_loss = 0.004352
# epoch 245 | train_loss = 0.004413 | val_loss = 0.004294
# epoch 246 | train_loss = 0.004402 | val_loss = 0.004346
# epoch 247 | train_loss = 0.004437 | val_loss = 0.004349
# epoch 248 | train_loss = 0.004432 | val_loss = 0.004326
# epoch 249 | train_loss = 0.004382 | val_loss = 0.004398
# epoch 250 | train_loss = 0.004385 | val_loss = 0.004356
# epoch 251 | train_loss = 0.004376 | val_loss = 0.004380
# epoch 252 | train_loss = 0.004389 | val_loss = 0.004350
# epoch 253 | train_loss = 0.004363 | val_loss = 0.004433
# epoch 254 | train_loss = 0.004366 | val_loss = 0.004380
# epoch 255 | train_loss = 0.004349 | val_loss = 0.004378
# epoch 256 | train_loss = 0.004347 | val_loss = 0.004366
# epoch 257 | train_loss = 0.004336 | val_loss = 0.004370
# epoch 258 | train_loss = 0.004356 | val_loss = 0.004359
# epoch 259 | train_loss = 0.004357 | val_loss = 0.004394
# epoch 260 | train_loss = 0.004394 | val_loss = 0.004349
# epoch 261 | train_loss = 0.004373 | val_loss = 0.004356
# epoch 262 | train_loss = 0.004357 | val_loss = 0.004374
# epoch 263 | train_loss = 0.004371 | val_loss = 0.004351
# epoch 264 | train_loss = 0.004348 | val_loss = 0.004344
# epoch 265 | train_loss = 0.004329 | val_loss = 0.004355
# epoch 266 | train_loss = 0.004325 | val_loss = 0.004331
# epoch 267 | train_loss = 0.004320 | val_loss = 0.004342
# epoch 268 | train_loss = 0.004316 | val_loss = 0.004340
# epoch 269 | train_loss = 0.004320 | val_loss = 0.004333
# epoch 270 | train_loss = 0.004312 | val_loss = 0.004376
# epoch 271 | train_loss = 0.004309 | val_loss = 0.004300
# epoch 272 | train_loss = 0.004316 | val_loss = 0.004334
# epoch 273 | train_loss = 0.004353 | val_loss = 0.004365
# epoch 274 | train_loss = 0.004357 | val_loss = 0.004314
# epoch 275 | train_loss = 0.004305 | val_loss = 0.004301
# epoch 276 | train_loss = 0.004308 | val_loss = 0.004314
# epoch 277 | train_loss = 0.004325 | val_loss = 0.004287
# epoch 278 | train_loss = 0.004266 | val_loss = 0.004240
# epoch 279 | train_loss = 0.004322 | val_loss = 0.004310
# epoch 280 | train_loss = 0.004287 | val_loss = 0.004322
# epoch 281 | train_loss = 0.004284 | val_loss = 0.004417
# epoch 282 | train_loss = 0.004299 | val_loss = 0.004372
# epoch 283 | train_loss = 0.004275 | val_loss = 0.004334
# epoch 284 | train_loss = 0.004283 | val_loss = 0.004412
# epoch 285 | train_loss = 0.004290 | val_loss = 0.004372
# epoch 286 | train_loss = 0.004302 | val_loss = 0.004285
# epoch 287 | train_loss = 0.004309 | val_loss = 0.004330
# epoch 288 | train_loss = 0.004294 | val_loss = 0.004281
# epoch 289 | train_loss = 0.004296 | val_loss = 0.004292
# epoch 290 | train_loss = 0.004299 | val_loss = 0.004298
# epoch 291 | train_loss = 0.004269 | val_loss = 0.004301
# epoch 292 | train_loss = 0.004285 | val_loss = 0.004269
# epoch 293 | train_loss = 0.004284 | val_loss = 0.004304
# epoch 294 | train_loss = 0.004274 | val_loss = 0.004266
# epoch 295 | train_loss = 0.004301 | val_loss = 0.004282
# epoch 296 | train_loss = 0.004311 | val_loss = 0.004242
# epoch 297 | train_loss = 0.004299 | val_loss = 0.004258
# epoch 298 | train_loss = 0.004271 | val_loss = 0.004296
# epoch 299 | train_loss = 0.004250 | val_loss = 0.004272
# epoch 300 | train_loss = 0.004269 | val_loss = 0.004296
# epoch 301 | train_loss = 0.004263 | val_loss = 0.004248
# epoch 302 | train_loss = 0.004253 | val_loss = 0.004227
# epoch 303 | train_loss = 0.004234 | val_loss = 0.004284
# epoch 304 | train_loss = 0.004262 | val_loss = 0.004227
# epoch 305 | train_loss = 0.004258 | val_loss = 0.004243
# epoch 306 | train_loss = 0.004299 | val_loss = 0.004213
# epoch 307 | train_loss = 0.004304 | val_loss = 0.004197
# epoch 308 | train_loss = 0.004278 | val_loss = 0.004225
# epoch 309 | train_loss = 0.004264 | val_loss = 0.004211
# epoch 310 | train_loss = 0.004262 | val_loss = 0.004261
# epoch 311 | train_loss = 0.004236 | val_loss = 0.004269
# epoch 312 | train_loss = 0.004242 | val_loss = 0.004313
# epoch 313 | train_loss = 0.004268 | val_loss = 0.004251
# epoch 314 | train_loss = 0.004223 | val_loss = 0.004305
# epoch 315 | train_loss = 0.004228 | val_loss = 0.004186
# epoch 316 | train_loss = 0.004219 | val_loss = 0.004153
# epoch 317 | train_loss = 0.004226 | val_loss = 0.004197
# epoch 318 | train_loss = 0.004229 | val_loss = 0.004231
# epoch 319 | train_loss = 0.004244 | val_loss = 0.004139
# epoch 320 | train_loss = 0.004253 | val_loss = 0.004151
# epoch 321 | train_loss = 0.004258 | val_loss = 0.004149
# epoch 322 | train_loss = 0.004251 | val_loss = 0.004145
# epoch 323 | train_loss = 0.004233 | val_loss = 0.004186
# epoch 324 | train_loss = 0.004228 | val_loss = 0.004210
# epoch 325 | train_loss = 0.004192 | val_loss = 0.004145
# epoch 326 | train_loss = 0.004203 | val_loss = 0.004164
# epoch 327 | train_loss = 0.004237 | val_loss = 0.004224
# epoch 328 | train_loss = 0.004241 | val_loss = 0.004191
# epoch 329 | train_loss = 0.004211 | val_loss = 0.004141
# epoch 330 | train_loss = 0.004206 | val_loss = 0.004162
# epoch 331 | train_loss = 0.004249 | val_loss = 0.004161
# epoch 332 | train_loss = 0.004240 | val_loss = 0.004176
# epoch 333 | train_loss = 0.004239 | val_loss = 0.004170
# epoch 334 | train_loss = 0.004218 | val_loss = 0.004107
# epoch 335 | train_loss = 0.004194 | val_loss = 0.004258
# epoch 336 | train_loss = 0.004218 | val_loss = 0.004219
# epoch 337 | train_loss = 0.004217 | val_loss = 0.004237
# epoch 338 | train_loss = 0.004205 | val_loss = 0.004216
# epoch 339 | train_loss = 0.004185 | val_loss = 0.004258
# epoch 340 | train_loss = 0.004202 | val_loss = 0.004268
# epoch 341 | train_loss = 0.004185 | val_loss = 0.004257
# epoch 342 | train_loss = 0.004205 | val_loss = 0.004274
# epoch 343 | train_loss = 0.004161 | val_loss = 0.004198
# epoch 344 | train_loss = 0.004208 | val_loss = 0.004196
# epoch 345 | train_loss = 0.004203 | val_loss = 0.004203
# epoch 346 | train_loss = 0.004204 | val_loss = 0.004228
# epoch 347 | train_loss = 0.004212 | val_loss = 0.004168
# epoch 348 | train_loss = 0.004225 | val_loss = 0.004185
# epoch 349 | train_loss = 0.004191 | val_loss = 0.004168
# epoch 350 | train_loss = 0.004169 | val_loss = 0.004151
# epoch 351 | train_loss = 0.004184 | val_loss = 0.004204
# epoch 352 | train_loss = 0.004195 | val_loss = 0.004211
# epoch 353 | train_loss = 0.004196 | val_loss = 0.004165
# epoch 354 | train_loss = 0.004196 | val_loss = 0.004187
# epoch 355 | train_loss = 0.004169 | val_loss = 0.004172
# epoch 356 | train_loss = 0.004206 | val_loss = 0.004176
# epoch 357 | train_loss = 0.004199 | val_loss = 0.004209
# epoch 358 | train_loss = 0.004206 | val_loss = 0.004129
# epoch 359 | train_loss = 0.004178 | val_loss = 0.004184
# epoch 360 | train_loss = 0.004171 | val_loss = 0.004143
# epoch 361 | train_loss = 0.004202 | val_loss = 0.004127
# epoch 362 | train_loss = 0.004184 | val_loss = 0.004148
# epoch 363 | train_loss = 0.004166 | val_loss = 0.004184
# epoch 364 | train_loss = 0.004190 | val_loss = 0.004184
# epoch 365 | train_loss = 0.004171 | val_loss = 0.004179
# epoch 366 | train_loss = 0.004162 | val_loss = 0.004148
# epoch 367 | train_loss = 0.004157 | val_loss = 0.004152
# epoch 368 | train_loss = 0.004157 | val_loss = 0.004165
# epoch 369 | train_loss = 0.004158 | val_loss = 0.004151
# epoch 370 | train_loss = 0.004158 | val_loss = 0.004166
# epoch 371 | train_loss = 0.004189 | val_loss = 0.004175
# epoch 372 | train_loss = 0.004151 | val_loss = 0.004205
# epoch 373 | train_loss = 0.004163 | val_loss = 0.004227
# epoch 374 | train_loss = 0.004151 | val_loss = 0.004173
# epoch 375 | train_loss = 0.004143 | val_loss = 0.004106
# epoch 376 | train_loss = 0.004160 | val_loss = 0.004167
# epoch 377 | train_loss = 0.004156 | val_loss = 0.004227
# epoch 378 | train_loss = 0.004163 | val_loss = 0.004181
# epoch 379 | train_loss = 0.004182 | val_loss = 0.004174
# epoch 380 | train_loss = 0.004183 | val_loss = 0.004164
# epoch 381 | train_loss = 0.004142 | val_loss = 0.004259
# epoch 382 | train_loss = 0.004144 | val_loss = 0.004155
# epoch 383 | train_loss = 0.004138 | val_loss = 0.004156
# epoch 384 | train_loss = 0.004132 | val_loss = 0.004148
# epoch 385 | train_loss = 0.004153 | val_loss = 0.004159
# epoch 386 | train_loss = 0.004167 | val_loss = 0.004156
# epoch 387 | train_loss = 0.004153 | val_loss = 0.004145
# epoch 388 | train_loss = 0.004169 | val_loss = 0.004141
# epoch 389 | train_loss = 0.004174 | val_loss = 0.004108
# epoch 390 | train_loss = 0.004128 | val_loss = 0.004153
# epoch 391 | train_loss = 0.004155 | val_loss = 0.004113
# epoch 392 | train_loss = 0.004158 | val_loss = 0.004156
# epoch 393 | train_loss = 0.004179 | val_loss = 0.004085
# epoch 394 | train_loss = 0.004175 | val_loss = 0.004098
# epoch 395 | train_loss = 0.004156 | val_loss = 0.004140
# epoch 396 | train_loss = 0.004160 | val_loss = 0.004088
# epoch 397 | train_loss = 0.004133 | val_loss = 0.004073
# epoch 398 | train_loss = 0.004141 | val_loss = 0.004082
# epoch 399 | train_loss = 0.004159 | val_loss = 0.004088
# epoch 400 | train_loss = 0.004138 | val_loss = 0.004146
# [TRAINED ERROR | SRCNN] test_MAE=0.004073 | test_RMSE=0.007697

# %% [markdown]
# ### Check for physical violations

# %%
# Load ranges for denormalising
RANGES_PATH = Path.cwd() / "ranges.py"
ns = runpy.run_path(str(RANGES_PATH))
RANGES = ns["RANGES"]

vmin = float(RANGES[variable][0])
vmax = float(RANGES[variable][1])

# Which variables have to be non-negative in physical units?
NONNEG_VARS = {
    "2m_temperature",
    "mean_surface_downward_long_wave_radiation_flux",
    "mean_surface_downward_short_wave_radiation_flux",
    "specific_humidity",
    "surface_pressure",
    "total_precipitation",
}
need_nonneg = (variable in NONNEG_VARS)

# Helper for calculating reduction percentages
def calculate_reduction(b, t):
    if b is None or t is None:
        return None
    b = float(b)
    t = float(t)
    if not math.isfinite(b) or not math.isfinite(t):
        return None
    if b == 0.0:
        return 0.0 if t == 0.0 else None
    return 100.0 * (b - t) / b

#=========================================================================================#

# Calculate the baseline violations and add to report
negative_pixels_total = 0
total_pixels = 0

mse_sum = 0.0
mse_count = 0

with torch.no_grad():
    for x, _ in test_loader:
        x = x.to(device, non_blocking=True)

        pred = x

        pred_phys = pred * (vmax - vmin) + vmin
        x_phys    = x    * (vmax - vmin) + vmin

        if need_nonneg:
            negative_pixels_total += (pred_phys < 0).sum().item()
            total_pixels += pred_phys.numel()

        pred_lr = F.avg_pool2d(pred_phys, kernel_size=2, stride=2)
        x_lr    = F.avg_pool2d(x_phys,    kernel_size=2, stride=2)

        diff = pred_lr - x_lr
        mse_sum += (diff * diff).sum().item()
        mse_count += diff.numel()

baseline_mean_consistency_rmse = float(math.sqrt(mse_sum / max(mse_count, 1)))
baseline_negatives_per_million = 1000000*(float(negative_pixels_total/max(total_pixels, 1))) if need_nonneg else None
    
bpm_str = f"{baseline_negatives_per_million:.6f}" if baseline_negatives_per_million is not None else "NA"
print(f"[BASELINE VIOLATION | IDENTITY MODEL] mean_consistency_rmse = {baseline_mean_consistency_rmse:.6f} | negatives_per_million = {bpm_str}")
    
report["baseline_violation"] = {
    "mean_consistency_rmse": baseline_mean_consistency_rmse,
    "negatives_per_million": baseline_negatives_per_million,
}

#=========================================================================================#

# Load the best checkpoint and evaluate violations of the test set
ckpt_path_best = run_dir / "best_model.pt"
ckpt = torch.load(ckpt_path_best, map_location=device)
model.load_state_dict(ckpt["state_dict"])
model.to(device)
model.eval()

# Calculate the trained violations and add to report
negative_pixels_total = 0
total_pixels = 0

mse_sum = 0.0
mse_count = 0

model.eval()
with torch.no_grad():
    for x, _ in test_loader:
        x = x.to(device, non_blocking=True)

        pred = model(x)

        pred_phys = pred * (vmax - vmin) + vmin
        x_phys    = x    * (vmax - vmin) + vmin

        if need_nonneg:
            negative_pixels_total += (pred_phys < 0).sum().item()
            total_pixels += pred_phys.numel()

        pred_lr = F.avg_pool2d(pred_phys, kernel_size=2, stride=2)
        x_lr    = F.avg_pool2d(x_phys,    kernel_size=2, stride=2)

        diff = pred_lr - x_lr
        mse_sum += (diff * diff).sum().item()
        mse_count += diff.numel()

trained_mean_consistency_rmse = float(math.sqrt(mse_sum / max(mse_count, 1)))
trained_negatives_per_million = 1000000*(float(negative_pixels_total/max(total_pixels, 1))) if need_nonneg else None
    
tpm_str = f"{trained_negatives_per_million:.6f}" if trained_negatives_per_million is not None else "NA"
print(f"[TRAINED VIOLATION | SRCNN] mean_consistency_rmse = {trained_mean_consistency_rmse:.6f} | negatives_per_million = {tpm_str}")
    
report["trained_violation"] = {
    "mean_consistency_rmse": trained_mean_consistency_rmse,
    "negatives_per_million": trained_negatives_per_million,
}

#=========================================================================================#

# Calculate how much the model performace improved
report["violation_reduction"] = {
    "mean_consistency_rmse": calculate_reduction(baseline_mean_consistency_rmse, trained_mean_consistency_rmse),
    "negatives_per_million": calculate_reduction(baseline_negatives_per_million, trained_negatives_per_million),
}

# Save the whole report in the working directory
def scrub_json(x):
    if isinstance(x, float):
        return None if (math.isnan(x) or math.isinf(x)) else x
    if isinstance(x, dict):
        return {k: scrub_json(v) for k, v in x.items()}
    if isinstance(x, list):
        return [scrub_json(v) for v in x]
    return x

with open(report_path, "w", encoding="utf-8") as f:
    json.dump(scrub_json(report), f, indent=2, sort_keys=False, allow_nan=False)
# Out:
# [BASELINE VIOLATION | IDENTITY MODEL] mean_consistency_rmse = 0.000000 | negatives_per_million = 0.000000
# [TRAINED VIOLATION | SRCNN] mean_consistency_rmse = 0.148398 | negatives_per_million = 0.000000
