# %% [markdown]
# ### Packages + Configuration

# %%
# 1. Packages
import runpy
import numpy as np
import netCDF4
from pathlib import Path

# 2. Configuration
YEARS = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
VARIABLES = ["2m_temperature",
             "10m_u_component_of_wind",
             "10m_v_component_of_wind",
             "mean_surface_downward_long_wave_radiation_flux",
             "mean_surface_downward_short_wave_radiation_flux",
             "specific_humidity",
             "surface_pressure",
             "total_precipitation"]
NORM_NAME = "zero_one"

# 3. Input and output paths
BASE = Path.cwd()
IN_DIR = BASE / "input_raw"
OUT_DIR = BASE / "input_labels"
OUT_DIR.mkdir(exist_ok=True)

# 4. File for saving ranges of values (useful for normalising and denormalising)
RANGES_PATH = BASE / "ranges.py"

if RANGES_PATH.exists():
    ns = runpy.run_path(str(RANGES_PATH))
    RANGES = ns.get("RANGES", {})
    RANGES = {k: [float(v[0]), float(v[1])] for k, v in RANGES.items()}
else:
    RANGES = {}

# %% [markdown]
# ### Helper Functions

# %%
# 5. If masked values exist, turn to NaN, then cast values to float32
def to_float_nan(a):
    if np.ma.isMaskedArray(a):
        a = a.filled(np.nan)
    return np.asarray(a, dtype=np.float32)

# 6. NaN values will be filled using mean of non-NaN values
def fill_nan_mean(a: np.ndarray) -> np.ndarray:
    if not np.isnan(a).any():
        return a
    m = np.nanmean(a)
    if np.isnan(m):
        m = 0.0
    return np.nan_to_num(a, nan=float(m)).astype(np.float32, copy=False)

# 7. Generate label
def hr_to_lr_up(HR: np.ndarray) -> np.ndarray:
    H, W = HR.shape
    H2, W2 = (H // 2) * 2, (W // 2) * 2
    HRc = HR[:H2, :W2]

    blocks = np.ascontiguousarray(HRc).reshape(H2 // 2, 2, W2 // 2, 2)
    LR_small = np.nanmean(blocks, axis=(1, 3)).astype(np.float32)
    LR_up = np.repeat(np.repeat(LR_small, 2, axis=0), 2, axis=1).astype(np.float32)
    return LR_up

# 8. Normalization helper
def minmax_stats(y: np.ndarray) -> tuple[float, float]:
    vmin = float(np.min(y))
    vmax = float(np.max(y))
    if vmax - vmin < 1e-12:
        vmax = vmin + 1.0
    return vmin, vmax

# 9. Normalizer
def to_zero_one(a: np.ndarray, vmin: float, vmax: float) -> np.ndarray:
    return ((a - vmin) / (vmax - vmin)).astype(np.float32, copy=False)

# %% [markdown]
# ### Main loop

# %%
# 10. loop over all years and variables
for year in YEARS:
    nc_path = IN_DIR / f"{year}.nc"
    with netCDF4.Dataset(nc_path, "r") as ds:
        for variable in VARIABLES:
            var = ds.variables[variable]
            T = int(var.shape[0])
            H = int(var.shape[1])
            W = int(var.shape[2])

            HR = np.empty((T, 1, H, W), dtype=np.float32)
            for t in range(T):
                hr = to_float_nan(var[t, :, :])
                hr = fill_nan_mean(hr)

                # This specific variable has small negative noise, so we clamp it
                if variable == "mean_surface_downward_short_wave_radiation_flux":
                    hr = np.maximum(hr, 0.0).astype(np.float32, copy=False)
    
                HR[t, 0] = hr

            vmin, vmax = minmax_stats(HR)

            # 11. Turn current year's range into floats
            vmin_f, vmax_f = float(vmin), float(vmax)

            # 12. Add variable if not yet in dictionary
            if variable not in RANGES:
                RANGES[variable] = [vmin_f, vmax_f]
                changed = True
                
            # 13. If already there, update if necessary
            else:
                old = RANGES[variable]
                new_min = min(old[0], vmin_f)
                new_max = max(old[1], vmax_f)
                changed = (new_min != old[0]) or (new_max != old[1])
                old[0], old[1] = new_min, new_max
            
            # 14. Create if doesn't exist or save if changes were made
            if (not RANGES_PATH.exists()) or changed:
                with open(RANGES_PATH, "w", encoding="utf-8") as f:
                    f.write("RANGES = {\n")
                    for k in sorted(RANGES.keys()):
                        f.write(f'    "{k}": [{RANGES[k][0]}, {RANGES[k][1]}],\n')
                    f.write("}\n")
        
            X = np.empty_like(HR)
            Y = np.empty_like(HR)

            for t in range(T):
                hr = HR[t, 0]
                lr_up = hr_to_lr_up(hr)

                X[t, 0] = to_zero_one(lr_up, vmin, vmax)
                Y[t, 0] = to_zero_one(hr,   vmin, vmax)

            OUT_DIR_VAR = OUT_DIR / f"{variable}"
            OUT_DIR_VAR.mkdir(exist_ok=True)
            out_path = OUT_DIR_VAR / f"{year}_{variable}.npz"
            np.savez_compressed(
                out_path,
                X=X,
                Y=Y,
                norm=NORM_NAME,
                vmin=np.float32(vmin),
                vmax=np.float32(vmax),
            )
            print(f"Saved {out_path.name} | X,Y={X.shape} | range = {NORM_NAME} [{vmin}, {vmax}]")
# Out:
# Saved 2001_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [193.45382690429688, 318.35064697265625]
# Saved 2001_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-34.052146911621094, 30.364177703857422]
# Saved 2001_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-30.46213150024414, 31.31575584411621]
# Saved 2001_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [44.725563049316406, 488.61151123046875]
# Saved 2001_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 485.0629577636719]
# Saved 2001_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [6.416160545086314e-07, 0.02964499592781067]
# Saved 2001_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [49037.703125, 106520.15625]
# Saved 2001_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.02144767716526985]
# Saved 2002_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [196.93980407714844, 320.7333679199219]
# Saved 2002_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-35.56136703491211, 31.64499855041504]
# Saved 2002_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-29.469825744628906, 35.135948181152344]
# Saved 2002_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [49.48981857299805, 482.51092529296875]
# Saved 2002_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 486.9911804199219]
# Saved 2002_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [1.1630821745711728e-06, 0.028224725276231766]
# Saved 2002_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [49187.3046875, 105743.859375]
# Saved 2002_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.021161604672670364]
# Saved 2003_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [195.93255615234375, 320.07373046875]
# Saved 2003_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-36.537742614746094, 30.364503860473633]
# Saved 2003_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-30.784366607666016, 33.451019287109375]
# Saved 2003_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [48.0613899230957, 487.7748718261719]
# Saved 2003_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 484.0775146484375]
# Saved 2003_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [9.82831920737226e-07, 0.02934441529214382]
# Saved 2003_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [48958.37109375, 105550.7890625]
# Saved 2003_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.020516881719231606]
# Saved 2004_2m_temperature.npz | X,Y=(366, 1, 180, 360) | range = zero_one [195.1038818359375, 318.1513671875]
# Saved 2004_10m_u_component_of_wind.npz | X,Y=(366, 1, 180, 360) | range = zero_one [-32.33301544189453, 30.03981590270996]
# Saved 2004_10m_v_component_of_wind.npz | X,Y=(366, 1, 180, 360) | range = zero_one [-32.190277099609375, 32.53908920288086]
# Saved 2004_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(366, 1, 180, 360) | range = zero_one [40.73412322998047, 490.82281494140625]
# Saved 2004_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(366, 1, 180, 360) | range = zero_one [0.0, 486.7812194824219]
# Saved 2004_specific_humidity.npz | X,Y=(366, 1, 180, 360) | range = zero_one [8.778209803494974e-07, 0.027575235813856125]
# Saved 2004_surface_pressure.npz | X,Y=(366, 1, 180, 360) | range = zero_one [49109.19140625, 105780.8828125]
# Saved 2004_total_precipitation.npz | X,Y=(366, 1, 180, 360) | range = zero_one [0.0, 0.01599119044840336]
# Saved 2005_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [195.28616333007812, 320.33697509765625]
# Saved 2005_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-36.29643630981445, 30.35943603515625]
# Saved 2005_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-29.87013053894043, 36.67264938354492]
# Saved 2005_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [44.485679626464844, 493.9218444824219]
# Saved 2005_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 485.59954833984375]
# Saved 2005_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [9.223544452652277e-07, 0.02852644957602024]
# Saved 2005_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [48802.65625, 106301.0234375]
# Saved 2005_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.021116243675351143]
# Saved 2006_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [192.01934814453125, 319.1703186035156]
# Saved 2006_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-35.636898040771484, 30.399120330810547]
# Saved 2006_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-32.1613883972168, 34.251808166503906]
# Saved 2006_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [45.6541862487793, 497.72344970703125]
# Saved 2006_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 487.31219482421875]
# Saved 2006_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [7.025546437944286e-07, 0.02945959009230137]
# Saved 2006_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [49183.81640625, 105978.453125]
# Saved 2006_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.022414246574044228]
# Saved 2007_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [195.4408416748047, 319.5655517578125]
# Saved 2007_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-32.68672180175781, 32.326419830322266]
# Saved 2007_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-29.195396423339844, 32.74235534667969]
# Saved 2007_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [46.4354248046875, 496.1397705078125]
# Saved 2007_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 484.8854064941406]
# Saved 2007_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [9.708739980851533e-07, 0.0294124074280262]
# Saved 2007_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [49399.984375, 105621.75]
# Saved 2007_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.019160659983754158]
# Saved 2008_2m_temperature.npz | X,Y=(366, 1, 180, 360) | range = zero_one [194.844482421875, 320.10015869140625]
# Saved 2008_10m_u_component_of_wind.npz | X,Y=(366, 1, 180, 360) | range = zero_one [-38.01714324951172, 31.126096725463867]
# Saved 2008_10m_v_component_of_wind.npz | X,Y=(366, 1, 180, 360) | range = zero_one [-31.030597686767578, 33.60087966918945]
# Saved 2008_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(366, 1, 180, 360) | range = zero_one [43.32051467895508, 487.087890625]
# Saved 2008_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(366, 1, 180, 360) | range = zero_one [0.0, 486.7586669921875]
# Saved 2008_specific_humidity.npz | X,Y=(366, 1, 180, 360) | range = zero_one [8.38651260437473e-07, 0.02877099998295307]
# Saved 2008_surface_pressure.npz | X,Y=(366, 1, 180, 360) | range = zero_one [48785.5390625, 105887.6015625]
# Saved 2008_total_precipitation.npz | X,Y=(366, 1, 180, 360) | range = zero_one [0.0, 0.01915382780134678]
# Saved 2009_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [197.012451171875, 319.98565673828125]
# Saved 2009_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-35.16529083251953, 30.44965171813965]
# Saved 2009_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-31.699703216552734, 34.002132415771484]
# Saved 2009_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [48.2878532409668, 487.1488952636719]
# Saved 2009_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 484.1702575683594]
# Saved 2009_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [1.4094023299549008e-06, 0.027842188253998756]
# Saved 2009_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [49426.734375, 105756.109375]
# Saved 2009_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.0240823682397604]
# Saved 2010_2m_temperature.npz | X,Y=(365, 1, 180, 360) | range = zero_one [194.86614990234375, 319.99725341796875]
# Saved 2010_10m_u_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-33.82000732421875, 28.437564849853516]
# Saved 2010_10m_v_component_of_wind.npz | X,Y=(365, 1, 180, 360) | range = zero_one [-32.95780944824219, 29.5916748046875]
# Saved 2010_mean_surface_downward_long_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [44.70058822631836, 489.9228515625]
# Saved 2010_mean_surface_downward_short_wave_radiation_flux.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 484.966796875]
# Saved 2010_specific_humidity.npz | X,Y=(365, 1, 180, 360) | range = zero_one [8.359826892956335e-07, 0.031333696097135544]
# Saved 2010_surface_pressure.npz | X,Y=(365, 1, 180, 360) | range = zero_one [49045.1484375, 106391.3046875]
# Saved 2010_total_precipitation.npz | X,Y=(365, 1, 180, 360) | range = zero_one [0.0, 0.01676187664270401]
